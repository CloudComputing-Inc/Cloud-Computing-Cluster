# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
df = pd.read_json('signalmedia-1m.jsonl', lines=True)

# %%
df.head()
# Out:
#                                      id  \
# 0  f7ca322d-c3e8-40d2-841f-9d7250ac72ca
# 1  609772bc-0672-4db5-8516-4c025cfd54ca
# 2  1aa9d1b0-e6ba-4a48-ad0c-66552d896aac
# 3  719699f9-47be-4bc7-969b-b53a881c95ae
# 4  a080f99a-07d9-47d1-8244-26a540017b7a
#
#                                              content  \
# 0  VETERANS saluted Worcester's first ever breakf...
# 1  New Product Gives Marketers Access to Real Key...
# 2  Home »\rStyle » The Return Of The Nike Air Max...
# 3  NYMag.com Daily Intelligencer Vulture The Cut ...
# 4  KUALA LUMPUR, Sept 15 (MySinchew) -- The Kuala...
#
#                                                title media-type  \
# 0  Worcester breakfast club for veterans gives hu...       News
# 1  Jumpshot Gives Marketers Renewed Visibility In...       News
# 2  The Return Of The Nike Air Max Sensation Has 8...       Blog
# 3   This New Dating App Will Ruin Your Internet Game       Blog
# 4                  Pay up or face legal action: DBKL       News
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   id          1000000 non-null  object
#  1   content     1000000 non-null  object
#  2   title       1000000 non-null  object
#  3   media-type  1000000 non-null  object
#  4   source      1000000 non-null  object
#  5   published   1000000 non-null  object
# dtypes: object(6)
# memory usage: 45.8+ MB

# %%
engine = create_engine('sqlite:///articles.db')

# %%
df.to_sql(name='articles', con=engine)
# Out:
# 1000000

# %%
sql_df = pd.read_sql_table(table_name='articles', con='sqlite:///articles.db')

# %%
sql_df
# Out:
#          index                                    id  \
# 0            0  f7ca322d-c3e8-40d2-841f-9d7250ac72ca
# 1            1  609772bc-0672-4db5-8516-4c025cfd54ca
# 2            2  1aa9d1b0-e6ba-4a48-ad0c-66552d896aac
# 3            3  719699f9-47be-4bc7-969b-b53a881c95ae
# 4            4  a080f99a-07d9-47d1-8244-26a540017b7a
# ...        ...                                   ...
# 999995  999995  ad1dfe61-164b-4fd8-8ef3-38d676f41831
# 999996  999996  383864ab-4880-46d0-8625-44ab43f489bc
# 999997  999997  36c044d8-4522-4a28-a92c-a8e994742188
# 999998  999998  374ff291-51c3-453e-ab06-c18dd2d880a0
# 999999  999999  c463033c-21a8-4085-ba81-f894ab0ddf5d
#
#                                                   content  \
# 0       VETERANS saluted Worcester's first ever breakf...
# 1       New Product Gives Marketers Access to Real Key...
# 2       Home »\rStyle » The Return Of The Nike Air Max...
# 3       NYMag.com Daily Intelligencer Vulture The Cut ...
# ...
